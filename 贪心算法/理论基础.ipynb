# %% [markdown]
# ![image.png](attachment:image.png)
#
# # 贪心算法
# > 通过在每个阶段选择本阶段的局部最优，从而达到全局最优
#
# # 什么时候使用贪心算法
# 如果 可以通过局部最优得到全局最优，那么就可以使用贪心算法
#
# 举不出反例的时候就可以试一试贪心
#
# 手动模拟一下感觉可以局部最优推出整体最优，而且想不到反例，那么就试一试贪心——
#   - 如果我每次都选择最优的，可以保证最后结果也是最优的吗？
#
#
# # 一般步骤
# - 问题分解：得到几个子问题
# - 选择策略
# - 求解每一个子问题的最优解
# - 局部最优堆叠得到全局最优解
#
# 其实就是先找到局部最优，最后将所有局部最优合成为全局最优
