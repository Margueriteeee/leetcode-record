# %% [markdown]
# # 理论基础
# 链表：通过指针串联在一起的线性结构，链表上的每个节点由两部分组成：
# - 数据域
# - 指针域（存放指向下一个结点的指针）
# - 最后一个节点的指针指向null
#
# 链表的入口节点（头节点）称为head
#
# ## 链表的类型
# ### 单链表
# 每个节点的指针域指向下一个节点
# 最后一个结点的指针为空 null
# ![image-2.png](attachment:image-2.png)
#
# ### 双链表
# 每个节点由两个指针域：
# - 分别指向当前节点的下一个节点和上一个节点
# - ![image.png](attachment:image.png)
#
# **双链表**既可以前行查询也可以后向查询
#
# ### 循环链表
# 最后一个节点中的指针域指向头节点
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 链表的存储方式
# 链表在内存中是 **非连续分布的** ！！！
# 链表中的每个节点通过指针域相互链接
# 内存由操作系统进行分配
#
# ## 链表的定义

# %%
# C/C++
struct ListNode{
    int val;  //元素值
    ListNode *next;  // 指向下一个结点的指针
    ListNode(int x) : val(x), next(NULL) {}  // 节点的构造函数
}

# 节点初始化
ListNode* heda = new ListNode(5);

# %% [markdown]
# # 链表的操作
# ## 删除节点
# 要删除D节点：
# - 把 C 节点的next指针指向 E 节点
# - c++中最好在删除节点后释放该节点的内存
# - Java、python有自己的内存回收机制，无需手动释放
# - ![image.png](attachment:image.png)
#
# ## 添加节点
# 添加 F 节点：
# - 把 C 节点的指针指向新节点 F
# - 把 F 节点的指针指向 D
#
# PS: 删除和添加节点都是O(1)操作，不会影响到其他节点
# 如果要删除特定位置，例如第三个节点，则需要从 head 查找到第二个节点通过next指针进行操作
# 有了查找操作后的时间复杂度变成了 O(n)
#
# ![image-2.png](attachment:image-2.png)
#
# **对比**：
# - 数组的长度是固定的，如果想改动数组的长度需要重新定义数组
# - 链表的长度不固定，可以动态的修改，适合数据量不固定，频繁增删、较少查询的场景

# %%
# python 的链表定义  
class ListNode:
    def __init__(self, val, next=None):
        self.val = val
        self.next = next
