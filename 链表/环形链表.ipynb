# %% [markdown]
# # 142 环形链表
# 给定一个链表，如果有环返回环的第一个节点。无环则返回null
#
# ## 双指针法
# fast 每次移动两个节点，low 每次移动一个节点
# 如果链表没有环，是一条直线，那么两个指针不可能相遇
#
# 如果两个指针相遇了， 则说明一定有环，而且两个指针是在环里相遇的。
# 速度差 = 1，二者的路程差是 1 的整数倍，因此只要相遇肯定有环
# 而且相遇的时候，快指针肯定在环里已经转了**至少一圈**
# 快指针入环两圈内必定追上慢指针
# 而慢指针在第一圈的时候一定可以被快指针给追上
#
# 从头结点出发一个指针，从相遇节点 也出发一个指针，这两个指针每次只走一个节点， 那么当这两个指针相遇的时候就是 环形入口的节点。
#
# ![image.png](attachment:image.png)

# %%
# 双指针法
class Soluion:
    def detectCycle(self, head:ListNode) -> ListNode:
        slow = head
        fast = head

        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next   # 快指针一次走两个节点
            # 相遇则存在环
            if slow == fast:
                # 相遇后开始找环的入口
                # 两个指针分别放在链表开头和相遇节点
                slow = head
                while slow != fast:
                    slow = slow.next
                    fast = fast.next
                return slow
        
        return None  # 两指针不相遇就没有环

# %%
# 集合法
class Solution:
    def detectCycle(self, head:ListNode) -> ListNode:
        visited = set()

        while head:
            if head in visited:
                return head   # 在已访问过的集合中重复出现则为环的入口
            
            visited.add(head)
            head = head.next

        return None
