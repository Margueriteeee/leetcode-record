# %% [markdown]
# # 栈与队列总结
#
# 栈和队列在内存中的分布不是连续的
#
# 匹配问题都是 **栈** 的强项
# - 括号匹配
# - 字符串去重
# - 逆波兰表达式
#
# **单调队列**的核心思想是抓主要矛盾
# - 没必要维护所有的元素，保证最大的元素在队头，队列元素单调递增或递减即可
#
# 前k个大数问题
# 三步走：统计频率-对频率排序-只要前k个
# 使用 **优先级队列**
#
# 保持队列中元素有序使用的是小顶堆：借助优先级队列实现 heapq
