# %% [markdown]
# # 哈希表理论基础
# Hash table: 哈希表 / 散列表
#
# > 哈希表是根据关键码的值而直接进行访问的数据结构
# eg：数组就是一张哈希表，关键码：索引下标
#
# 哈希表能解决的问题：**快速判断一个元素是否出现在某个集合里**
#
# 相比于遍历搜索（枚举）O(N)的时间复杂度，哈希表的时间复杂度为O(1)
# 把一个元素映射到哈希表，查找的时候通过索引直接判断是否属于某个集合
# 映射的过程就是哈希函数
#
# ## 哈希函数 hash function
# ![image.png](attachment:image.png)
#
# - hashCode 把姓名通过特定编码方式将其他数据格式转化为不同的数值
# - 取模操作：确保转化后的数值小于 tableSize
#
# 如果需要映射的对象数量大于哈希表的大小，必定有几个对象被映射到哈希表中同一索引的位置
#
# ## 哈希碰撞
# 两个元素被映射到同一下标的现象
# ![image-2.png](attachment:image-2.png)
#
# 两种解决方法：拉链法和线性探测法
#
# ### 拉链法
# 在发生冲突的位置构建一个链表，依次存储发生冲突的元素
# - 适当选择哈希表的大小
# - 让数组空值不至于太大减小浪费，也不要让需要查找的链表太长
# ![image-3.png](attachment:image-3.png)
#
# ### 线性探测法
# 前提：保证 **tableSize > dataSize**
# 借助哈希表中的空位解决碰撞
#
# - 发生冲突时如果冲突位置已有元素，则寻找下一个空位来存放冲突的元素
# ![image-4.png](attachment:image-4.png)
#
# ## 常见的三种哈希结构
# ### 1.数组
#
# ### 2.集合 set
# ### 3.映射 map
#
# python中主要通过 字典 和 集合 实现哈希算法
#
# ## 总结
# **要快速判断一个元素是否出现集合里的时候，就要考虑哈希法**
# 哈希法本质是空间换时间，使用额外的数组空间来存放数据才能实现快速查找
#
# 使用哈希法的场景：
# - 判断一个元素是否出现过
# - 一个元素是否出现在集合中
