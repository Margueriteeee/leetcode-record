# %% [markdown]
# # 右旋字符串
# 输入：给定字符串 s 和 正整数 k
# 要求：把字符串后面 k 个字符移到字符串的前面
# 输出：移位后的字符串
#
# ## 思路
# 其实就是向右循环移位的过程，移除字符串的移到字符串前面
#
# k 其实把字符串分成了两段：长为k的一段，和长为 n-k 的一段
# - 先整体倒叙
# - 两端子串内部倒叙
#
# ![image.png](attachment:image.png)

# %%
k = int(intput())
s = input()

# 通过切片翻转两个字串
# python中字符串不可修改，需要额外空间
s = s[len(s) - k : ] + s[: len(s) - k]
print(s)

# %% [markdown]
# **python一句话结束战斗啊！切片伟大的神！**
