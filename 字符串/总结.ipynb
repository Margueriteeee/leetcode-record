# %% [markdown]
# # 字符串大总结
# 字符串本质还是数组，只不过元素是字符
#
# python中的string是不能直接修改的，需要转换成list（string）再进行操作
#
# ## 双指针法
# 很多填充类问题，基本思路都可以先把数组扩容到填充后的大小，然后**从后向前**进行操作
#
# 注意分析时间复杂度，过于简单的题不要直接使用库函数
#
# ## 反转系列
# 当需要固定一段一段去处理字符串的时候，可以想想在for循环的表达式上做文章
#
# double 翻转 = 不反转
#
# ## KMP
# 解决 **在字符串中查找目标字符串的匹配** 问题
