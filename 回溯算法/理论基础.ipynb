# %% [markdown]
# # 回溯法
# 回溯是一种搜索方式，是递归的副产品
#
# 有递归就有回溯
#
# 回溯函数也就是递归函数
#
# ## 回溯法的效率
# 回溯的本质是**穷举**，穷举出所有可能然后选出想要的答案
#
# 提高回溯效率的方法是剪枝
#
# ## 回溯法解决的问题
# - 组合问题：N 个数里面按规则找出k个数的集合
# - 切割问题：一个字符串按一定规则有几种切割方式
# - 子集问题：一个N个数的集合中有多少符合条件的子集
# - 排列问题：N 个数按规则全排列有多少种排列方式
#   - 排列是强调顺序的，组合不强调顺序
# - 棋盘问题：N皇后，解数独等等
#
# ## 回溯法理解
# 回溯法能解决的问题都可以抽象为树形结构
#
# 回溯法解决的都是在集合中递归查找子集，所以集合的大小构成树的宽度
# 递归的深度构成了树的深度
#
# 递归一定是要有终止条件的，所以必然是一颗高度有限的树（N叉树）
#
# ## 回溯三部曲
# 1. 参数和返回值
#    - 参数：先写逻辑，逻辑需要哪些参数就写哪些参数
#    - 返回值：一般是none
#    - 回溯函数 backtracing
#
# 2. 终止条件：
#    - 二叉树中一般遍历到叶子结点的时候就结束本层的递归
#    - 回溯函数中类似，满足 终止条件 时存放好结果，然后返回
#
# 3. 遍历过程
#    - 回溯遍历过程中，集合的大小构成树的宽度，递归次数构成树的深度
#  - ![image.png](attachment:image.png)

# %%
# 回溯法模板

def backtracing(参数)：
    if(终止条件)：
        存放结果
        return
    
    for(选择：本层集合中元素（集合大小 = 树节点孩子数量):
        处理节点
        回溯函数递归 backtracing(路径，选择列表)
        回溯，撤销处理结果

    return
